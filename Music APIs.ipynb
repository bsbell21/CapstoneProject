# %%
import requests

# %% [markdown]
# Client ID for Mobile Client, Web API, and eyeQ
#
# 6492160-C28FECBBB02D8CDEB1B3472122ABE3E4
#
# License information for GNSDK
#
# Client ID: 6492160
#
# Client Tag: C28FECBBB02D8CDEB1B3472122ABE3E4

# %%
client_id = '6492160'

# %%
r = requests.get('https://c<' + client_id + '>.web.cddbp.net/webapi/json/1.0/radio/create?\')
# Out:
#   File "<ipython-input-34-60f670ba57a5>", line 1
#     r = requests.get('https://c<' + client_id + '>.web.cddbp.net/webapi/json/1.0/radio/create?\')
#                                                                                                 ^
# SyntaxError: EOL while scanning string literal

# %%
r.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-4138a680e0b6> in <module>()
# ----> 1 r.text
#
# NameError: name 'r' is not defined

# %%
user_id = requests.get('https://c' + client_id + '.web.cddbp.net/webapi/json/1.0/radio/register')

# %%
user_id.content
# Out:
# '\n{\n        "MESSAGE":\n        [\n            {\n                "VALUE" : "Missing or bad CLIENT information."\n            }\n        ],\n        "RESPONSE":\n        [\n            {\n                "STATUS" : "ERROR"\n            }\n        ]\n}\n'

# %%
r2 = requests.get('https://c' + client_id + '.web.cddbp.net/webapi/json/1.0/radio/create?\')
# Out:
#   File "<ipython-input-38-a6194fee1565>", line 1
#     r2 = requests.get('https://c' + client_id + '.web.cddbp.net/webapi/json/1.0/radio/create?\')
#                                                                                                ^
# SyntaxError: EOL while scanning string literal

# %%
'https://c1234567.web.cddbp.net/webapi/json/1.0/radio/create?artist_name=led+zeppelin&track_title=black+dog&client=1234567-288F907CEB2B3FB67605FFCFD23052F4&user=259329808546684785-439F373A2D5522BC2DC371C47913B976'
# Out:
# 'https://c1234567.web.cddbp.net/webapi/json/1.0/radio/create?artist_name=led+zeppelin&track_title=black+dog&client=1234567-288F907CEB2B3FB67605FFCFD23052F4&user=259329808546684785-439F373A2D5522BC2DC371C47913B976'

# %%
r3 = requests.get('https://c6492160.web.cddbp.net/webapi/json/1.0/radio/register')

# %%
r3.content
# Out:
# '\n{\n        "MESSAGE":\n        [\n            {\n                "VALUE" : "Missing or bad CLIENT information."\n            }\n        ],\n        "RESPONSE":\n        [\n            {\n                "STATUS" : "ERROR"\n            }\n        ]\n}\n'

# %%
import pygn

# %%
clientID = '6492160-C28FECBBB02D8CDEB1B3472122ABE3E4'
userID = pygn.register(clientID)

# %%
userID
# Out:
# '263553327070248397-C6D5CBA2FDB9F59634C0E8DD3598FF62'

# %%
metadata = pygn.search(clientID=clientID, userID=userID, artist='Chance the Rapper', track='Cocoa Butter Kisses')

# %%
metadata
# Out:
# {'album_art_url': 'http://akamai-b.cdn.cddbp.net/cds/2.0/cover/6E4C/4747/CE8B/171E_medium_front.jpg?cid=6492160',
#  'album_artist_name': 'Chance The Rapper',
#  'album_gnid': '341932222-135AF17627FF97BA05CBED7BDE7CF09E',
#  'album_title': 'Acid Rap',
#  'album_year': '2013',
#  'artist_bio_url': 'http://web.content.cddbp.net/cds/2.0?id=53D7034F0FB07A06&client=6492160&class=biography&type=text/plain&tag=02dzeaBeXM6cuaULIsmBQCtoTYAfLLTVDY1EUDCkjIDsoV5wxXiEhcug',
#  'artist_era': {'1': {'ID': '29483', 'TEXT': "2000's"},
#   '2': {'ID': '29493', 'TEXT': "Late 2000's"}},
#  'artist_image_url': '',
#  'artist_origin': {'1': {'ID': '29889', 'TEXT': 'North America'},
#   '2': {'ID': '29908', 'TEXT': 'United States'},
#   '3': {'ID': '30180', 'TEXT': 'Illinois'},
#   '4': {'ID': '30595', 'TEXT': 'Chicago'}},
#  'artist_type': {'1': {'ID': '29422', 'TEXT': 'Male'},
#   '2': {'ID': '29426', 'TEXT': 'Male'}},
#  'genre': {'1': {'ID': '25316', 'TEXT': 'Urban'},
# ...

# %%
radio = pygn.createRadio(clientID=clientID, userID=userID, artist=['Chance the Rapper','Jack Johnson', 'Madonna'], track=['Cocoa Butter Kisses', 'Gone', 'Like a Virgin'], count = '20', multiple_seeds = True)
# Out:
# <RESPONSES>
#  <RESPONSE STATUS="OK">
#    <RADIO>
#       <ID>3e5ef9776719c44c0a564534c748846f</ID>
#    </RADIO>
#    <ALBUM ORD="1">
#       <GN_ID>7404744-37ABD7D5EA756F7F60FDEA0C4A227E1E</GN_ID>
#       <ARTIST>Donna Summer</ARTIST>
#       <ARTIST_ORIGIN ORD="1" ID="29889">North America</ARTIST_ORIGIN>
#       <ARTIST_ORIGIN ORD="2" ID="29908">United States</ARTIST_ORIGIN>
#       <ARTIST_ORIGIN ORD="3" ID="30188">Massachusetts</ARTIST_ORIGIN>
#       <ARTIST_ORIGIN ORD="4" ID="30612">Boston</ARTIST_ORIGIN>
#       <ARTIST_TYPE ORD="1" ID="29423">Female</ARTIST_TYPE>
#       <ARTIST_TYPE ORD="2" ID="29443">Female</ARTIST_TYPE>
#       <ARTIST_ERA ORD="1" ID="29486">1970&apos;s</ARTIST_ERA>
#       <TITLE>Donna Summer</TITLE>
#       <GENRE ORD="1" NUM="105216" ID="35470">Electronica</GENRE>
#       <GENRE ORD="2" NUM="177011" ID="65033">Disco</GENRE>
#       <GENRE ORD="3" NUM="62046" ID="25638">Disco</GENRE>
#       <XID DATASOURCE="deezer-album-id">1968791</XID>
# ...

# %%
radio = pygn.createRadio(clientID=clientID, userID=userID, artist=['Jay-Z', 'Nas', 'Big L'], track=["Feelin' it", 'One Love', 'M.V.P.'], count = '20', multiple_seeds = True)
# Out:
# <RESPONSES>
#  <RESPONSE STATUS="OK">
#    <RADIO>
#       <ID>9d8ccb0d8716db23803f7b265d1dbf72</ID>
#    </RADIO>
#    <ALBUM ORD="1">
#       <GN_ID>4963642-D5539FB0DD4BF06C1AC079C520721C57</GN_ID>
#       <ARTIST>Das EFX</ARTIST>
#       <ARTIST_ORIGIN ORD="1" ID="29889">North America</ARTIST_ORIGIN>
#       <ARTIST_ORIGIN ORD="2" ID="29908">United States</ARTIST_ORIGIN>
#       <ARTIST_ORIGIN ORD="3" ID="30213">Virginia</ARTIST_ORIGIN>
#       <ARTIST_TYPE ORD="1" ID="29422">Male</ARTIST_TYPE>
#       <ARTIST_TYPE ORD="2" ID="29432">Male Duo</ARTIST_TYPE>
#       <ARTIST_ERA ORD="1" ID="29484">1990&apos;s</ARTIST_ERA>
#       <TITLE>Dead Serious</TITLE>
#       <GENRE ORD="1" NUM="61344" ID="25316">Urban</GENRE>
#       <GENRE ORD="2" NUM="105257" ID="35503">Western Hip-Hop/Rap</GENRE>
#       <GENRE ORD="3" NUM="62135" ID="25693">East Coast Rap</GENRE>
#       <XID DATASOURCE="deezer-album-id">273336</XID>
#       <TRACK_COUNT>10</TRACK_COUNT>
#       <TRACK>
# ...

# %%
for song in radio:
    print song['album_artist_name'], song['track_title']
# Out:
# Das EFX They Want EFX
# Raekwon Criminology
# Meek Mill Believe It
# LL Cool J Loungin
# Ol' Dirty Bastard Shimmy Shimmy Ya
# Wu-Tang Clan Protect Ya Neck
# Jay-Z Change Clothes
# Lil' Kim Crush On You
# Gang Starr Take It Personal
# Nas The World Is Yours
# Naughty By Nature O.P.P.
# Method Man Bring The Pain
# Mobb Deep Temperature's Rising
# A$AP Ferg Shabba
# 50 Cent Disco Inferno
# Black Sheep The Choice Is Yours (Revisited)
# Lloyd Banks On Fire
# GZA Liquid Swords
# Cam'ron Oh Boy

# %%
radio2 = pygn.createRadio(clientID=clientID, userID=userID, artist='abc', track='xyc', count = '20', multiple_seeds = False)
# Out:
# <RESPONSES>
#  <RESPONSE STATUS="OK">
#    <RADIO>
#       <ID>f426795fc1413bc652499d0212dde471</ID>
#    </RADIO>
#    <ALBUM ORD="1">
#       <GN_ID>224333490-3080A38A7EE2B169188442CCDEE729E9</GN_ID>
#       <ARTIST>Various Artists</ARTIST>
#       <ARTIST_ORIGIN ORD="1" ID="29894">Western Europe</ARTIST_ORIGIN>
#       <ARTIST_ORIGIN ORD="2" ID="29967">United Kingdom</ARTIST_ORIGIN>
#       <ARTIST_TYPE ORD="1" ID="29422">Male</ARTIST_TYPE>
#       <ARTIST_TYPE ORD="2" ID="29436">Male Group</ARTIST_TYPE>
#       <ARTIST_ERA ORD="1" ID="42877">2010&apos;s</ARTIST_ERA>
#       <ARTIST_ERA ORD="2" ID="42889">Early 2010&apos;s</ARTIST_ERA>
#       <TITLE>Hits For Kids - Greatest Hits</TITLE>
#       <GENRE ORD="1" NUM="61340" ID="25312">Alternative &amp; Punk</GENRE>
#       <GENRE ORD="2" NUM="176777" ID="65023">New Wave Pop</GENRE>
#       <GENRE ORD="3" NUM="105340" ID="35552">New Wave Pop</GENRE>
#       <XID DATASOURCE="deezer-album-id">693798</XID>
# ...

# %%
for song in radio2:
    print song['album_artist_name'], song['track_title']
# Out:
# Various Artists My Way
# Culture Club Miss Me Blind
# Fine Young Cannibals She Drives Me Crazy
# Wet Wet Wet Sweet Little Mystery
# Level 42 Lessons In Love
# ABC Tears Are Not Enough
# Eurythmics Would I Lie To You?
# Duran Duran Hungry Like The Wolf
# Arcadia Election Day
# ABC Solace - A Mexican Serenade
# Ultravox Vienna
# ABC How To Be A Millionaire
# Tears For Fears Sowing The Seeds Of Love
# Scritti Politti The Sweetest Girl
# Pseudo Echo Funky Town
# ABC Be Near Me
# Katrina & The Waves Walking On Sunshine
# Living In A Box Living In A Box
# A Flock Of Seagulls Wishing (If I Had a Photograph of You)

# %%
type(radio2)
# Out:
# list

# %%
radio2
# Out:
# [{'album_art_url': 'http://akamai-b.cdn.cddbp.net/cds/2.0/cover/7222/504F/BD86/0BE2_medium_front.jpg?cid=6492160',
#   'album_artist_name': 'ABC',
#   'album_gnid': '8910025-DF8DA8897F5B43E7FD7D6B30DC11E306',
#   'album_title': 'The Lexicon Of Love',
#   'album_year': '',
#   'artist_bio_url': 'http://web.content.cddbp.net/cds/2.0?id=9BBC7D2D7B683E23&client=6492160&class=biography&type=text/plain&tag=02JS-Sy1idWAE08Jw8GCymN5wC2uk6L0s4vVV5OhmiNdOq9XNdK.s93w',
#   'artist_era': {'1': {'ID': '29485', 'TEXT': "1980's"}},
#   'artist_image_url': 'http://akamai-b.cdn.cddbp.net/cds/2.0/image-artist/E824/159B/38EC/6D3C_medium_front.jpg?cid=6492160',
#   'artist_origin': {'1': {'ID': '29894', 'TEXT': 'Western Europe'},
#    '2': {'ID': '29967', 'TEXT': 'United Kingdom'}},
#   'artist_type': {'1': {'ID': '29422', 'TEXT': 'Male'},
#    '2': {'ID': '29436', 'TEXT': 'Male Group'}},
#   'genre': {'1': {'ID': '25312', 'TEXT': 'Alternative & Punk'},
# ...

# %% [markdown]
# ## Spotify

# %%
rs = requests.get('https://api.spotify.com/

# %% [markdown]
# ## Echonest

# %% [markdown]
# Your API Key: IHQR7II9KIYTTAPKS
#
# Your Consumer Key: 368f158957a9b30e8844bddca8d5b222
#
# Your Shared Secret: xFSrM/KBTeisHQ9CHHdwew

# %%
from pyechonest import config
config.ECHO_NEST_API_KEY="IHQR7II9KIYTTAPKS"

# %%
from pyechonest import artist
ctr = artist.Artist('Chance the Rapper')
print "Artists similar to: %s:" % (ctr.name,)
for similar_artist in ctr.similar: print "\t%s" % (similar_artist.name,)
# Out:
# Artists similar to: Chance the Rapper:
# 	Joey Bada$$
# 	Chuck Inglish
# 	Ab-Soul
# 	Schoolboy Q
# 	Chief Keef
# 	Rockie Fresh
# 	Dizzy Wright
# 	Casey Veggies
# 	A$AP Rocky
# 	Boldy James
# 	Troy Ave
# 	MellowHigh
# 	ASAP Ferg
# 	Smoke DZA
# 	Kendrick Lamar

# %%
from pyechonest import playlist
radio_ctr = playlist.basic(artist = 'Chance the Rapper')
radio_ctr
# Out:
# [<song - Juice>,
#  <song - Track Two>,
#  <song - Ridin' Roun Town>,
#  <song - One of One>,
#  <song - Came Thru/Easily (feat. Ab-Soul & Mac Miller)>,
#  <song - What They Want>,
#  <song - King Push>,
#  <song - Limos featuring Teyana Taylor>,
#  <song - 3Hunna>,
#  <song - After School>,
#  <song - Boomin'>,
#  <song - Dip>,
#  <song - Everywhere I Go>,
#  <song - HighLife>,
#  <song - Bonfire>]

# %%
import pyen
en = pyen.Pyen("IHQR7II9KIYTTAPKS")

# %%
en.get('artist/similar', name='Chance the Rapper')
# Out:
# {u'artists': [{u'id': u'ARLTCGU13798C212D5', u'name': u'Joey Bada$$'},
#   {u'id': u'ARKGDMY122BCFC9B7E', u'name': u'Chuck Inglish'},
#   {u'id': u'ARUVHYV12FA3238377', u'name': u'Ab-Soul'},
#   {u'id': u'ARREQCK1269FB2EE5C', u'name': u'Schoolboy Q'},
#   {u'id': u'ARZWIUY137E73EDEA5', u'name': u'Chief Keef'},
#   {u'id': u'ARXZXCX134B4F5F2CF', u'name': u'Rockie Fresh'},
#   {u'id': u'ARTCCYI136658E7EB7', u'name': u'Dizzy Wright'},
#   {u'id': u'ARJPVIB12E7C5F327B', u'name': u'Casey Veggies'},
#   {u'id': u'ARVKMMF133F5CF74A6', u'name': u'A$AP Rocky'},
#   {u'id': u'ARXNQFU133C8070F88', u'name': u'Boldy James'},
#   {u'id': u'ARGQWAV1269FCD3DEE', u'name': u'Troy Ave'},
#   {u'id': u'ARHBMMT13B48012D63', u'name': u'MellowHigh'},
#   {u'id': u'ARZVHGB135592014BE', u'name': u'ASAP Ferg'},
#   {u'id': u'AR8VVK71187B98E6F8', u'name': u'Smoke DZA'},
#   {u'id': u'AREJQVO12C1DF51FFE', u'name': u'Kendrick Lamar'}],
#  u'status': {u'code': 0, u'message': u'Success', u'version': u'4.2'}}

# %%
en.get('artist/profile', name = 'Chance the Rapper', bucket = 'genre')
# Out:
# {u'artist': {u'genres': [{u'name': u'alternative hip hop'},
#    {u'name': u'underground hip hop'}],
#   u'id': u'ARXWJJE13B4EDDC072',
#   u'name': u'Chance the Rapper'},
#  u'status': {u'code': 0, u'message': u'Success', u'version': u'4.2'}}

# %%
en.get('artist/terms', name = 'Chance the Rapper')
# Out:
# {u'start': 0,
#  u'status': {u'code': 0, u'message': u'Success', u'version': u'4.2'},
#  u'terms': [{u'frequency': 0.8812180804511437,
#    u'name': u'rap',
#    u'weight': 0.654747225647349},
#   {u'frequency': 0.5751024921221216,
#    u'name': u'hip hop',
#    u'weight': 0.4007398273736128}]}

# %%
en.get('artist/terms', name = 'Chance the Rapper', type = 'style')
# Out:
# {u'start': 0,
#  u'status': {u'code': 0, u'message': u'Success', u'version': u'4.2'},
#  u'terms': [{u'frequency': 0.8812180804511437,
#    u'name': u'rap',
#    u'weight': 0.654747225647349},
#   {u'frequency': 0.5751024921221216,
#    u'name': u'hip hop',
#    u'weight': 0.4007398273736128}]}

# %%
artist_ids =  ['AR2ZPMX1187FB4E4B6', 'ARF8HTQ1187B9AE693', 'ARL93GT1187B9A1057', 'ARR3ONV1187B9A2F59', 'ARJS9GN1187FB578C4']

# %%
playlist_1 = en.get('playlist/basic', artist_id = artist_ids, type = 'artist-radio')

# %%
playlist_1
# Out:
# {u'songs': [{u'artist_id': u'ARF8HTQ1187B9AE693',
#    u'artist_name': u'Daft Punk',
#    u'id': u'SONIEVP131677130E7',
#    u'title': u'Around The World'},
#   {u'artist_id': u'ARR3ONV1187B9A2F59',
#    u'artist_name': u'Muse',
#    u'id': u'SOESRGR13A7B34F902',
#    u'title': u'Panic Station'},
#   {u'artist_id': u'AR2ZPMX1187FB4E4B6',
#    u'artist_name': u'Vampire Weekend',
#    u'id': u'SOTAUJW13EC791A6B8',
#    u'title': u'Hannah Hunt'},
#   {u'artist_id': u'ARL93GT1187B9A1057',
#    u'artist_name': u'Metric',
#    u'id': u'SONLCTW12A58A7BB70',
#    u'title': u'Collect Call'},
#   {u'artist_id': u'ARJS9GN1187FB578C4',
#    u'artist_name': u'Deadmau5',
#    u'id': u'SOBZINV13521E69625',
#    u'title': u'Sofi Needs A Ladder'},
#   {u'artist_id': u'AR3NPVS1187FB5108F',
#    u'artist_name': u'Les Rythmes Digitales',
#    u'id': u'SOABCZB12A58A7D13E',
#    u'title': u"Hey You What's That Sound ?"},
#   {u'artist_id': u'ARJ7KF01187B98D717',
#    u'artist_name': u'Coldplay',
# ...

# %%
for song in playlist_1['songs']:
    print 'artist: %s, song: %s' % (song['artist_name'], song['title'])
# Out:
# artist: Daft Punk, song: Around The World
# artist: Muse, song: Panic Station
# artist: Vampire Weekend, song: Hannah Hunt
# artist: Metric, song: Collect Call
# artist: Deadmau5, song: Sofi Needs A Ladder
# artist: Les Rythmes Digitales, song: Hey You What's That Sound ?
# artist: Coldplay, song: A Sky Full of Stars
# artist: BSOD, song: This Is Also The Hook
# artist: Keane, song: Somewhere Only We Know
# artist: Ra Ra Riot, song: Boy
# artist: Daft Punk, song: Giorgio by Moroder
# artist: Metric, song: Stadium Love
# artist: Deadmau5, song: Professional Griefers
# artist: Muse, song: Uprising
# artist: Mirwais, song: Naïve Song

# %%
import pipeline_1110 as p

# %%
pr = p.PlaylistRecommender()

# %%
artist_groups = [['ARFIU2R1187B9927F9', 'ARH6W4X1187B99274F', 'ARH3S5S1187FB4F76B', 'ARQOBT71187FB4CCCA', 'ARIPLUN1187B99B9F9'], ['ARWA8AH1187FB3FC84', 'ARS8GNX1187B9B5141', 'ARSAIUN1187FB398D3', 'ARNBMT71187B993523', 'ARZZ5ZR1187FB4D149'], ['ARK9TRQ1187B99C095', 'AR32ML41187FB36D9A', 'ARVG4OK1187B9B6BD3', 'ARFC93D1187FB49D2E', 'ARAXU5Z1187B98FECD'], ['AR2ZPMX1187FB4E4B6', 'ARF8HTQ1187B9AE693', 'ARL93GT1187B9A1057', 'ARR3ONV1187B9A2F59', 'ARJS9GN1187FB578C4'], ['AR6AY7W1187B9AC569', 'AR6NYHH1187B9BA128', 'AR633SY1187B9AC3B9', 'ARRH63Y1187FB47783', 'ARBLDRW1187B9A05A1'], ['AR5JDDD1187FB460C4', 'ARB6OGR1187FB4D43D', 'ARFF4B41187FB48151', 'ARH0TST1187FB3F8F1', 'AR6XPWV1187B9ADAEB'], ['AROKAO61187FB38105', 'ART5MUE1187B98C961', 'ARPN0Y61187B9ABAA0', 'AR4ZYGI1187B995AA2', 'AR9O98A1187FB39621'], ['AR1E9AW1187B9AC8F6', 'AREPV2D1187FB5C1A1', 'ARFVYJI1187B9B8E13', 'ARHTAPO1187FB5AADE']]
pr.fit_multiple(artist_groups)
# Out:
# <bound method PlaylistRecommender.print_playlists of <pipeline_1110.PlaylistRecommender instance at 0x109f067e8>>

# %%
pr.print_playlists()
# Out:
# Playlist 0:
# artist: LCD Soundsystem, song: You Wanted A Hit
# artist: Beirut, song: Santa Fe
# artist: The Police, song: Walking On The Moon
# artist: Nirvana, song: Rape Me
# artist: Radiohead, song: Lotus Flower
# artist: Joe Jackson, song: Breaking Us In Two
# artist: Temple of the Dog, song: Say Hello 2 Heaven
# artist: Thom Yorke, song: A Brain In A Bottle
# artist: Foo Fighters, song: Best Of You
# artist: LCD Soundsystem, song: Home
# artist: Radiohead, song: Karma Police
# artist: Nirvana, song: Come As You Are
# artist: Beirut, song: A Candle's Fire
# artist: !!!, song: Heart Of Hearts
# artist: The Police, song: Wrapped Around Your Finger
# Playlist 1:
# artist: Interpol, song: My Blue Supreme
# artist: The Black Keys, song: She's Long Gone
# artist: Hot Chip, song: Over And Over
# artist: Air, song: Sexy Boy
# artist: Creedence Clearwater Revival, song: Have You Ever Seen The Rain
# artist: The White Stripes, song: We're Going To Be Friends
# ...

# %%
ctr_playlist = en.get('playlist/basic', artist = 'Chance the Rapper', type = 'artist-radio')

for song in ctr_playlist['songs']:
    print 'artist: %s, song: %s' % (song['artist_name'], song['title'])
# Out:
# artist: Chance the Rapper, song: Good Ass Intro (ft. BJ The Chicago Kid, Lili K., Kiara Lanier, Peter Cottontale, Will for the O'mys, & JP Floydd for Kids These Days)
# artist: Chief Keef, song: Love Sosa
# artist: Joey Bada$$, song: #LongLiveSteelo (feat. T'nah Apex)
# artist: A$AP Rocky, song: Fashion Killa
# artist: Schoolboy Q, song: Hands On The Wheel
# artist: ASAP Ferg, song: Let It Go
# artist: Troy Ave, song: My Grind
# artist: Sir Michael Rocks, song: Kill Switch
# artist: Flatbush Zombies, song: Palm Trees
# artist: Ab-Soul, song: Hunnid Stax (feat. ScHoolboy Q)
# artist: Smoke DZA, song: Substance Abuse
# artist: Pusha T, song: Hold On
# artist: Boldy James, song: Moochie
# artist: Alexander Spit, song: Down (prod. by KT The Terrible) [Instrumental]
# artist: Freddie Gibbs, song: Knicks

# %%
en.get('genre/similar', name='hip hop')
# Out:
# {u'genres': [{u'name': u'rap', u'similarity': 0.635443},
#   {u'name': u'hardcore hip hop', u'similarity': 0.468354},
#   {u'name': u'alternative hip hop', u'similarity': 0.425316},
#   {u'name': u'east coast hip hop', u'similarity': 0.407595},
#   {u'name': u'pop rap', u'similarity': 0.405063},
#   {u'name': u'old school hip hop', u'similarity': 0.397468},
#   {u'name': u'underground hip hop', u'similarity': 0.35443},
#   {u'name': u'gangster rap', u'similarity': 0.260759},
#   {u'name': u'trap music', u'similarity': 0.192405},
#   {u'name': u'dirty south rap', u'similarity': 0.174684},
#   {u'name': u'southern hip hop', u'similarity': 0.162025},
#   {u'name': u'turntablism', u'similarity': 0.146835},
#   {u'name': u'juggalo', u'similarity': 0.131646},
#   {u'name': u'crunk', u'similarity': 0.126582},
#   {u'name': u'hip pop', u'similarity': 0.101266}],
#  u'start': 0,
#  u'status': {u'code': 0, u'message': u'Success', u'version': u'4.2'},
#  u'total': 15}

# %%
en.get('artist/video', name='Chance the Rapper')
# Out:
# {u'start': 0,
#  u'status': {u'code': 0, u'message': u'Success', u'version': u'4.2'},
#  u'total': 105,
#  u'video': [{u'date_found': u'2014-10-25T00:00:00',
#    u'id': u'f86b8d07b6f1297ee47021c907e0c858',
#    u'image_url': u'http://i.ytimg.com/vi/aQCBgWGAQDo/default.jpg',
#    u'site': u'youtube.com',
#    u'title': u'Chance The Rapper (feat. Vic Mensa) - Family [Blended Babies Remix]',
#    u'url': u'http://www.youtube.com/watch?v=aQCBgWGAQDo&feature=youtube_gdata_player'},
#   {u'date_found': u'2014-09-20T00:00:00',
#    u'id': u'a0f5bd3f97896a13d8369c802c4469a9',
#    u'image_url': u'http://i.ytimg.com/vi/uHmUcJTgRXw/default.jpg',
#    u'site': u'youtube.com',
#    u'title': u'Juice - Chance The Rapper',
#    u'url': u'http://www.youtube.com/watch?v=uHmUcJTgRXw&feature=youtube_gdata_player'},
#   {u'date_found': u'2014-09-04T00:00:00',
#    u'id': u'a8220957317c4cf026149016dfc64bca',
#    u'image_url': u'http://i.ytimg.com/vi/13CNf9ahowo/default.jpg',
# ...

# %%
song_id = en.get('song/search', artist = 'Weezer', title = 'El Scorcho')['songs'][0]['id']
en.get('track/profile',id = song_id, bucket = 'audio_summary')
# Out:
# {u'status': {u'code': 0, u'message': u'Success', u'version': u'4.2'},
#  u'track': {u'audio_summary': {},
#   u'id': u'SOSLMMY146073E1766',
#   u'status': u'complete'}}

# %%
weez = requests.get('http://developer.echonest.com/api/v4/track/profile?api_key=IHQR7II9KIYTTAPKS&format=json&id=TRTLKZV12E5AC92E11&bucket=audio_summary').content

# %%
import json
weez_json = json.loads(weez)
weez_json
# Out:
# {u'response': {u'status': {u'code': 0,
#    u'message': u'Success',
#    u'version': u'4.2'},
#   u'track': {u'artist': u'Weezer',
#    u'audio_md5': u'e16bde82eaecd13bde9261b2710aa991',
#    u'audio_summary': {u'acousticness': 0.08863241469505381,
#     u'analysis_url': u'http://echonest-analysis.s3.amazonaws.com/TR/sH3nRgHBizHz2LT0ajgaKomIJNr5FYie3BemYM/3/full.json?AWSAccessKeyId=AKIAJRDFEY23UEVW42BQ&Expires=1415235077&Signature=bZfMFVdEXVjBoGjyAzUeKfu89/g%3D',
#     u'danceability': 0.5164314670162907,
#     u'duration': 243.64363,
#     u'energy': 0.6624323071153342,
#     u'instrumentalness': 0.00025195777658546426,
#     u'key': 1,
#     u'liveness': 0.12703360740225414,
#     u'loudness': -4.613,
#     u'mode': 1,
#     u'speechiness': 0.04183173788604305,
#     u'tempo': 74.694,
#     u'time_signature': 4,
#     u'valence': 0.5514032101047824},
#    u'catalog': u'7digital-AU',
#    u'foreign_id': u'7digital-AU:track:11123262',
# ...

# %%
param_dict = {'id': song_id, 'bucket': 'audio_summary', 'format': 'json'}

# %%
from pyechonest import track

# %%
tr = track.Track(track.track_from_id(song_id))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-c5853e308ebb> in <module>()
# ----> 1 tr = track.Track(track.track_from_id(song_id))
#
# TypeError: __init__() takes exactly 4 arguments (2 given)

# %%
track.track_from_id(str(song_id)).get_analysis()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-25-76b8d08cc2ac> in <module>()
# ----> 1 track.track_from_id(str(song_id)).get_analysis()
#
# /Users/Zipfian/anaconda/lib/python2.7/site-packages/pyechonest-8.0.2-py2.7.egg/pyechonest/track.pyc in get_analysis(self)
#     142                 raise Exception("Failed to create track analysis.")
#     143         else:
# --> 144             raise Exception("Failed to create track analysis.")
#     145
#     146
#
# Exception: Failed to create track analysis.

# %%
str(song_id)
# Out:
# 'SOSLMMY146073E1766'

# %%
# getting list of artist's genres
en.get('artist/profile', name='Chance the Rapper', bucket = ['genre', 'doc_counts'])
# Out:
# {u'artist': {u'doc_counts': {u'audio': 0,
#    u'biographies': 4,
#    u'blogs': 4280,
#    u'images': 11,
#    u'news': 998,
#    u'reviews': 18,
#    u'songs': 4,
#    u'video': 105},
#   u'genres': [{u'name': u'alternative hip hop'},
#    {u'name': u'underground hip hop'}],
#   u'id': u'ARXWJJE13B4EDDC072',
#   u'name': u'Chance the Rapper'},
#  u'status': {u'code': 0, u'message': u'Success', u'version': u'4.2'}}

# %%
en.get('song/identify', title = 'Juice', artist = 'Chance the Rapper', bucket = 'audio_summary')
# Out:
# {u'songs': [{u'error': u'need codes in query for fingerprint matching'}],
#  u'status': {u'code': 0, u'message': u'Success', u'version': u'4.2'}}

# %%
from pyechonest import catalog

# %%
ls
# Out:
# 1015_RecommendationSystems@                          recommend_init.py
# 1103_Recommender.ipynb                               recommend_init.pyc
# Echonest.ipynb                                       reinterestinmusicinformationretrievalcoffeechat/
# Music APIs.ipynb                                     reinterestinmusicinformationretrievalcoffeechat.zip
# SQLcode_msd.txt                                      taste_profile_usercat_120k.txt
# genre_sim_matrix1.txt                                taste_profile_usercat_120k_catalog.txt
# genre_sim_tot.txt                                    train_triplets.txt
# lastfm-1k/                                           train_triplets.txt.zip
# lastfm-dataset-360K/

# %%
with open('taste_profile_usercat_120k_catalog.txt') as f:
    i = 0
    for line in f:
        i += 1
        if i in range(10):
            print line
        if i == 1:
            cat = catalog.Catalog(line.encode('ascii', 'ignore'))
    print i
    print cat
# Out:
# ---------------------------------------------------------------------------
# EchoNestAPIError                          Traceback (most recent call last)
# <ipython-input-94-cc6d6f99b6bc> in <module>()
#       6             print line
#       7         if i == 1:
# ----> 8             cat = catalog.Catalog(line.encode('ascii', 'ignore'))
#       9     print i
#      10     print cat
#
# /Users/Zipfian/anaconda/lib/python2.7/site-packages/pyechonest-8.0.2-py2.7.egg/pyechonest/catalog.pyc in __init__(self, id, type, **kwargs)
#      76
#      77         """
# ---> 78         super(Catalog, self).__init__(id, type, **kwargs)
#      79
#      80     def __repr__(self):
#
# /Users/Zipfian/anaconda/lib/python2.7/site-packages/pyechonest-8.0.2-py2.7.egg/pyechonest/proxies.pyc in __init__(self, identifier, type, buckets, **kwargs)
#      65         if not all(ca in kwargs for ca in core_attrs):
# ...

# %%
df = pd.read_csv('taste_profile_usercat_120k_catalog.txt', header=None)

# %%
(len(df)/20)/60
# Out:
# 99

# %%
df[0].values[0]
# Out:
# 'CACHGYH1332EB0628E'

# %%
df.values[1][0]
# Out:
# 'CAKCLXJ1332EB06A11'

# %%
cat = catalog.Catalog(df.values[0][0])
# Out:
# ---------------------------------------------------------------------------
# EchoNestAPIError                          Traceback (most recent call last)
# <ipython-input-120-cc156af9bfaa> in <module>()
# ----> 1 cat = catalog.Catalog(df.values[0][0])
#
# /Users/Zipfian/anaconda/lib/python2.7/site-packages/pyechonest-8.0.2-py2.7.egg/pyechonest/catalog.pyc in __init__(self, id, type, **kwargs)
#      76
#      77         """
# ---> 78         super(Catalog, self).__init__(id, type, **kwargs)
#      79
#      80     def __repr__(self):
#
# /Users/Zipfian/anaconda/lib/python2.7/site-packages/pyechonest-8.0.2-py2.7.egg/pyechonest/proxies.pyc in __init__(self, identifier, type, buckets, **kwargs)
#      65         if not all(ca in kwargs for ca in core_attrs):
#      66             if util.short_regex.match(self.id) or util.long_regex.match(self.id) or util.foreign_regex.match(self.id):
# ---> 67                 profile = self.get_attribute('profile')
# ...

# %%
cat.get_item_dicts()
# Out:
# [{u'artist_id': u'ARWS2GP1187FB4CCD2',
#   u'artist_name': u'Atom and His Package',
#   u'date_added': u'2011-10-24T00:02:58',
#   u'foreign_id': u'CACHGYH1332EB0628E:song:1040441_usercat',
#   u'last_modified': u'2011-10-24T19:33:02',
#   u'play_count': 1,
#   u'request': {u'artist_id': u'ARWS2GP1187FB4CCD2',
#    u'item_id': u'1040441_usercat',
#    u'song_id': u'SOMKEUZ12A8C140023'},
#   u'song_id': u'SOMKEUZ12A8C140023',
#   u'song_name': u'Happy Birthday Ralph'},
#  {u'artist_id': u'ARGMGHN1187B9B4213',
#   u'artist_name': u'Gym Class Heroes',
#   u'date_added': u'2011-10-24T06:53:34',
#   u'foreign_id': u'CACHGYH1332EB0628E:song:10648482_usercat',
#   u'last_modified': u'2011-10-25T00:45:47',
#   u'play_count': 1,
#   u'request': {u'artist_id': u'ARGMGHN1187B9B4213',
#    u'item_id': u'10648482_usercat',
#    u'song_id': u'SOQSQOU12A58A77A24'},
#   u'song_id': u'SOQSQOU12A58A77A24',
#   u'song_name': u'Under The Bridge'},
#  {u'artist_id': u'ARF6ZTO1187FB3684F',
# ...

# %%
cat.get_item_dicts()[0]
# Out:
# ---------------------------------------------------------------------------
# EchoNestAPIError                          Traceback (most recent call last)
# <ipython-input-119-4c6138b7b334> in <module>()
# ----> 1 cat.get_item_dicts()[0]
#
# /Users/Zipfian/anaconda/lib/python2.7/site-packages/pyechonest-8.0.2-py2.7.egg/pyechonest/catalog.pyc in get_item_dicts(self, buckets, results, start, item_ids)
#     279         kwargs['bucket'] = buckets or []
#     280         kwargs['item_id'] = item_ids or []
# --> 281         response = self.get_attribute("read", results=results, start=start, **kwargs)
#     282         rval = ResultList(response['catalog']['items'])
#     283         if item_ids:
#
# /Users/Zipfian/anaconda/lib/python2.7/site-packages/pyechonest-8.0.2-py2.7.egg/pyechonest/proxies.pyc in get_attribute(self, *args, **kwargs)
#      92         else:
#      93             kwargs['name'] = self.id
# ---> 94         return super(CatalogProxy, self).get_attribute(*args, **kwargs)
# ...

# %%
from pymongo import MongoClient
# Out:
# [INFO] Start server at: ipc:///tmp/graphlab_server-36428 - Server binary: /Users/Zipfian/anaconda/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1415257767.log
# [INFO] GraphLab Server Version: 1.0.1

# %%
client = MongoClient("mongodb://localhost:27017/")

# %%
db = client["onefiftyk"]

# %%
collection = db.userlistendata

# %%
collection.insert(cat.get_item_dicts())
# Out:
# [ObjectId('545b2022b4ec8d873434d812'),
#  ObjectId('545b2022b4ec8d873434d813'),
#  ObjectId('545b2022b4ec8d873434d814'),
#  ObjectId('545b2022b4ec8d873434d815'),
#  ObjectId('545b2022b4ec8d873434d816'),
#  ObjectId('545b2022b4ec8d873434d817'),
#  ObjectId('545b2022b4ec8d873434d818'),
#  ObjectId('545b2022b4ec8d873434d819'),
#  ObjectId('545b2022b4ec8d873434d81a'),
#  ObjectId('545b2022b4ec8d873434d81b'),
#  ObjectId('545b2022b4ec8d873434d81c'),
#  ObjectId('545b2022b4ec8d873434d81d'),
#  ObjectId('545b2022b4ec8d873434d81e'),
#  ObjectId('545b2022b4ec8d873434d81f'),
#  ObjectId('545b2022b4ec8d873434d820')]

# %%
import time
print time.ctime()
time.sleep(2)
print time.ctime()
# Out:
# Wed Nov  5 23:57:50 2014
# Wed Nov  5 23:57:52 2014

# %%
cat
# Out:
# <catalog - f85c6de77b853f0b4d624a042129aee374db2637_tmp_catalog>

# %%
reload(r)
r.import_cat_data()

# %%
cat.get_item_dicts()[0]
# Out:
# {u'artist_id': u'ARB6OGR1187FB4D43D',
#  u'artist_name': u'M83',
#  u'date_added': u'2011-10-23T20:59:59',
#  u'foreign_id': u'CACNYVZ1332EB0BA9D:song:10286694_usercat',
#  u'last_modified': u'2011-10-23T20:12:07',
#  u'play_count': 1,
#  u'request': {u'artist_id': u'ARB6OGR1187FB4D43D',
#   u'item_id': u'10286694_usercat',
#   u'song_id': u'SOFMYVK12A58A7A675'},
#  u'song_id': u'SOFMYVK12A58A7A675',
#  u'song_name': u'Skin Of The Night'}

# %%
len(df.values)/120/60
# Out:
# 16

# %%
en.get('artist/profile', id = cat.get_item_dicts()[0]['artist_id'], bucket = 'genre')
# Out:
# {u'artist': {u'genres': [{u'name': u'indietronica'},
#    {u'name': u'nu gaze'},
#    {u'name': u'metropopolis'},
#    {u'name': u'dream pop'},
#    {u'name': u'synthpop'},
#    {u'name': u'r-neg-b'},
#    {u'name': u'alternative dance'},
#    {u'name': u'indie pop'}],
#   u'id': u'ARB6OGR1187FB4D43D',
#   u'name': u'M83'},
#  u'status': {u'code': 0, u'message': u'Success', u'version': u'4.2'}}

# %%
en.get('genre/list')['genres']
# Out:
# [{u'name': u'a cappella'},
#  {u'name': u'abstract'},
#  {u'name': u'abstract hip hop'},
#  {u'name': u'abstract idm'},
#  {u'name': u'accordion'},
#  {u'name': u'acid house'},
#  {u'name': u'acid jazz'},
#  {u'name': u'acid techno'},
#  {u'name': u'acousmatic'},
#  {u'name': u'acoustic blues'},
#  {u'name': u'acoustic pop'},
#  {u'name': u'adult standards'},
#  {u'name': u'african percussion'},
#  {u'name': u'african rock'},
#  {u'name': u'afrikaans'},
#  {u'name': u'afrobeat'},
#  {u'name': u'afrobeats'},
#  {u'name': u'aggrotech'},
#  {u'name': u'albanian pop'},
#  {u'name': u'album rock'},
#  {u'name': u'albuquerque indie'},
#  {u'name': u'alternative americana'},
#  {u'name': u'alternative country'},
#  {u'name': u'alternative dance'},
#  {u'name': u'alternative emo'},
#  {u'name': u'alternative hip hop'},
#  {u'name': u'alternative metal'},
#  {u'name': u'alternative metalcore'},
#  {u'name': u'alternative new age'},
#  {u'name': u'alternative pop'},
# ...

# %%
import recommend_init as r

# %%
reload(r)
# Out:
# <module 'recommend_init' from 'recommend_init.pyc'>

# %%
r.create_genre_similarity_matrix()
# Out:
# a cappella
# abstract
# abstract hip hop
# abstract idm
# accordion
# acid house
# acid jazz
# acid techno
# acousmatic
# acoustic blues
# acoustic pop
# adult standards
# african percussion
# african rock
# afrikaans
# afrobeat
# afrobeats
# aggrotech
# albanian pop
# album rock
# albuquerque indie
# alternative americana
# alternative country
# alternative dance
# alternative emo
# alternative hip hop
# alternative metal
# alternative metalcore
# alternative new age
# alternative pop
# alternative pop rock
# alternative r&b
# alternative rock
# ambeat
# ambient
# ambient dub techno
# ambient fusion
# ambient idm
# ambient psychill
# ambient trance
# anarcho-punk
# andean
# anime
# anime score
# anti-folk
# antiviral pop
# appalachian folk
# arab folk
# arab pop
# arabesk
# argentine rock
# armenian folk
# art rock
# athens indie
# atmospheric black metal
# atmospheric post rock
# atmospheric post-metal
# aussietronica
# austindie
# australian alternative rock
# australian country
# ...

# %%
en.get('genre/list', results = 2000)
# Out:
# {u'genres': [{u'name': u'a cappella'},
#   {u'name': u'abstract'},
#   {u'name': u'abstract hip hop'},
#   {u'name': u'abstract idm'},
#   {u'name': u'accordion'},
#   {u'name': u'acid house'},
#   {u'name': u'acid jazz'},
#   {u'name': u'acid techno'},
#   {u'name': u'acousmatic'},
#   {u'name': u'acoustic blues'},
#   {u'name': u'acoustic pop'},
#   {u'name': u'adult standards'},
#   {u'name': u'african percussion'},
#   {u'name': u'african rock'},
#   {u'name': u'afrikaans'},
#   {u'name': u'afrobeat'},
#   {u'name': u'afrobeats'},
#   {u'name': u'aggrotech'},
#   {u'name': u'albanian pop'},
#   {u'name': u'album rock'},
#   {u'name': u'albuquerque indie'},
#   {u'name': u'alternative americana'},
#   {u'name': u'alternative country'},
#   {u'name': u'alternative dance'},
#   {u'name': u'alternative emo'},
#   {u'name': u'alternative hip hop'},
#   {u'name': u'alternative metal'},
#   {u'name': u'alternative metalcore'},
#   {u'name': u'alternative new age'},
# ...

# %% [markdown]
# ## SoundCloud

# %% [markdown]
# Client ID: d9a53614ae4008ea7902cfc8ef39fef2
#
# Client Secret: 8819b3ab395fd1413f90505c6ac5b6e5
#
# end user authorization: https://soundcloud.com/connect
#
# token? https://api.soundcloud.com/oauth2/token

# %%
import json

# %%
soundcloud_client_id = 'd9a53614ae4008ea7902cfc8ef39fef2'
soundcloud_client_secret = '8819b3ab395fd1413f90505c6ac5b6e5'

# %%
r_sc = requests.get("http://api.soundcloud.com/users/benbellmusic/favorites.json?client_id=" + soundcloud_client_id)

# %%
favs = json.loads(str(r_sc.text.encode('ascii', 'ignore')))
len(favs)
# Out:
# 4

# %%
favs[0].keys()
# Out:
# [u'attachments_uri',
#  u'video_url',
#  u'track_type',
#  u'release_month',
#  u'original_format',
#  u'label_name',
#  u'duration',
#  u'id',
#  u'streamable',
#  u'user_id',
#  u'title',
#  u'favoritings_count',
#  u'commentable',
#  u'label_id',
#  u'download_url',
#  u'state',
#  u'downloadable',
#  u'policy',
#  u'waveform_url',
#  u'sharing',
#  u'description',
#  u'release_day',
#  u'purchase_url',
#  u'permalink',
#  u'comment_count',
#  u'purchase_title',
#  u'stream_url',
#  u'last_modified',
#  u'user',
#  u'genre',
#  u'isrc',
#  u'download_count',
#  u'permalink_url',
#  u'playback_count',
#  u'kind',
#  u'release_year',
#  u'license',
#  u'artwork_url',
#  u'created_at',
#  u'bpm',
#  u'uri',
#  u'original_content_size',
#  u'key_signature',
#  u'release',
#  u'tag_list',
#  u'embeddable_by']

# %%
print [i['title'] for i in favs]
# Out:
# [u'Brain Cells (Prod. by Peter Cottontale)', u'Haerts - Wings (Shlohmo Remix)', u'Rapsody - Lonely Thoughts Soundcloud (feat. Chance The Rapper, Big K.R.I.T.)', u'Bravado (FFFRRANNNO Remix)']

# %%
comments_sc =  requests.get("http://api.soundcloud.com/users/benbellmusic/comments.json?client_id=" + soundcloud_client_id)

# %%
comments_sc = json.loads(str(comments_sc.text.encode('ascii', 'ignore')))
len(favs)
# Out:
# 4

# %%
comments_sc[0]['id']
# Out:
# 208039645

# %%
comments_sc[1]
# Out:
# {u'body': u'Where can I download this - incredible!',
#  u'created_at': u'2013/11/14 16:50:50 +0000',
#  u'id': 145182108,
#  u'kind': u'comment',
#  u'timestamp': 1457642,
#  u'track_id': 119797581,
#  u'uri': u'https://api.soundcloud.com/comments/145182108',
#  u'user': {u'avatar_url': u'https://i1.sndcdn.com/avatars-000050521021-tpswkk-large.jpg',
#   u'id': 54432344,
#   u'kind': u'user',
#   u'last_modified': u'2014/11/03 18:27:22 +0000',
#   u'permalink': u'benbellmusic',
#   u'permalink_url': u'http://soundcloud.com/benbellmusic',
#   u'uri': u'https://api.soundcloud.com/users/54432344',
#   u'username': u'Ben Bell Music'},
#  u'user_id': 54432344}

# %%
json.loads(requests.get("http://api.soundcloud.com/tracks/13158665.json?client_id=" + soundcloud_client_id).text)['title']
# Out:
# u'Munching at Tiannas house'

# %%
def get_comments_and_title(userid):
    full_dict = []
    comments_sc =  requests.get("http://api.soundcloud.com/users/" + userid + "/comments.json?client_id=" + soundcloud_client_id)
    comments_sc = json.loads(str(comments_sc.text.encode('ascii', 'ignore')))
    for idx, comment in enumerate(comments_sc):
        full_dict.append(comment)
        song_id = str(comment['id'])
        r_song = requests.get("http://api.soundcloud.com/tracks/" + song_id + ".json?client_id=" + soundcloud_client_id)
        song_info = json.loads(r_song.text.encode('ascii', 'ignore'))
#         song_info = json.loads(requests.get("http://api.soundcloud.com/tracks/" + song_id + ".json?client_id=" + soundcloud_client_id).text)
        print song_info
        for key in song_info:
            full_dict[idx]['song_' + key] = song_info[key]
        
        print song_info['title']
        print comment['body']
    return full_dict

# %%
get_comments_and_title('benbellmusic')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-140-43cd22517188> in <module>()
# ----> 1 get_comments_and_title('benbellmusic')
#
# <ipython-input-139-b073a95d500d> in get_comments_and_title(userid)
#      13             full_dict[idx]['song_' + key] = song_info[key]
#      14
# ---> 15         print song_info['title']
#      16         print comment['body']
#      17     return full_dict
#
# KeyError: 'title'
# {u'errors': [{u'error_message': u'404 - Not Found'}]}

# %%
song_id = str(comments_sc[2]['id'])
r_song = requests.get("http://api.soundcloud.com/tracks/" + song_id + ".json?client_id=" + soundcloud_client_id)
song_info = json.loads(r_song.text.encode('ascii', 'ignore'))
song_info['title']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-162-3be3cfe28a4c> in <module>()
#       2 r_song = requests.get("http://api.soundcloud.com/tracks/" + song_id + ".json?client_id=" + soundcloud_client_id)
#       3 song_info = json.loads(r_song.text.encode('ascii', 'ignore'))
# ----> 4 song_info['title']
#
# KeyError: 'title'

# %%
r_song = requests.get("http://api.soundcloud.com/tracks/" + song_id + ".json?client_id=" + soundcloud_client_id)

# %%
r_song
# Out:
# <Response [404]>

# %%
comments_sc[1]['id']
# Out:
# 145175897

# %%
song_info
# Out:
# {u'errors': [{u'error_message': u'404 - Not Found'}]}

# %%
comments_sc[2]['body']
# Out:
# u'this is fiiiiire'

# %%
song_id
# Out:
# '145175897'
